# %%
import pandas as pd

# %%
df = pd.read_csv(r"data/01_raw/hktvmall_discounted_raw.csv")

# %%
df.columns
# Out:
# Index(['code', 'name', 'url', 'description', 'purchasable', 'stock',
#        'averageRating', 'numberOfReviews', 'summary', 'price', 'baseProduct',
#        'images', 'categories', 'potentialPromotions', 'variantOptions',
#        'score', 'brandName', 'storeCode', 'storeCodeOriginal', 'storeName',
#        'storeType', 'storeTypeDisplay', 'storeRating', 'chineseLocaleActive',
#        'deliveryModeName', 'deliveryModeCode', 'packingSpec',
#        'countryOfOrigin', 'storeTC', 'promotionPrice', 'labels',
#        'loyaltyPoint', 'priceList', 'colors', 'promotionText',
#        'promotionStyle', 'thresholdPromotion', 'invisible', 'recommendedPrice',
#        'savedPrice', 'productKeyword', 'primaryCatCode', 'isFlashSale',
#        'isEcoupon', 'numberOfVariants', 'isStockNotified', 'urgent',
#        'purchaseOption', 'reservable', 'quantity', 'userMax', 'store',
#        'deliveryLabel', 'includeRemovalService', 'isInsurance',
# ...

# %%
df.dtypes
# Out:
# code                        object
# name                        object
# url                         object
# description                 object
# purchasable                   bool
#                             ...
# packingHeight              float64
# packingDepth               float64
# perfectPartnerPromotion     object
# productVideoUrls            object
# numberOfColors             float64
# Length: 62, dtype: object

# %%
df.describe()
# Out:
#        averageRating  numberOfReviews  score  storeRating  loyaltyPoint  \
# count      10.000000        10.000000   10.0    10.000000          10.0
# mean        4.205579       194.600000    1.0     4.650000           0.0
# std         0.471942       176.239231    0.0     0.337474           0.0
# min         3.113636         8.000000    1.0     4.000000           0.0
# 25%         4.060013        71.250000    1.0     4.500000           0.0
# 50%         4.389520       151.000000    1.0     4.500000           0.0
# 75%         4.536189       227.750000    1.0     5.000000           0.0
# max         4.619048       503.000000    1.0     5.000000           0.0
#
#        numberOfVariants  purchaseOption  quantity  userMax  packingLength  \
# count         10.000000            10.0      10.0     10.0           10.0
# mean           1.500000             0.0       0.0      0.0            0.0
# std            1.581139             0.0       0.0      0.0            0.0
# ...

# %%
pd.options.display.max_columns = None

# %%
df
# Out:
#                           code                             name  \
# 0             H0228001_S_V0529                    $50禮劵 (1套11張)
# 1         H0888001_S_P10137077                         [原箱] 朝米水
# 2          H0888001_S_10137434   天然100%竹纖維萬用除菌消毒環保家居濕紙巾 (清新檸檬)
# 3          H0888001_S_10138319                         消毒藥水(檸檬)
# 4          H0888001_S_10132113                      全護ZERO配方漱口水
# 5         H0888001_S_P10020857                         [原箱] 蒸餾水
# 6           H0602001_S_TA07EAE  [專門店] TA07EAE  3/4 匹窗口式冷氣機[淨冷型]
# 7     H0246002_S_4713282766996                     杏仁茶 (原味不加糖)
# 8  H5037001_S_18-NP900PWI19_X2   [HKTV獨家] 星級酒店枕 (NP900PWI19) 2件
# 9  H0955001_S_DuHsiaoYueh01-01                     原味肉燥（大罐）300g
#
#                                                  url  \
# 0  main/%E9%B4%BB%E7%A6%8F%E5%A0%82/s/H0228001/%E...
# 1  main/CheckCheckCin/s/H1080007/%E8%B6%85%E7%B4%...
# 2  main/%E9%AB%98%E9%9C%B2%E6%BD%94/s/H1022001/%E...
# ...

# %%
df.iloc[0].labels
# Out:
# "[{'type': 'OFFER', 'name': 'Fixed price Discount (normal)', 'amount': None, 'loyaltyPoint': None}, {'type': 'REBATE', 'name': '0% Rewards', 'amount': 0.0, 'loyaltyPoint': '0'}]"

# %%
df.iloc[0].priceList
# Out:
# "[{'currencyIso': 'HKD', 'value': 550.0, 'priceType': 'BUY', 'formattedValue': '$ 550.00', 'minQuantity': None, 'maxQuantity': None, 'membershipLevel': 'NORMAL'}, {'currencyIso': 'HKD', 'value': 354.99997500000006, 'priceType': 'DISCOUNT', 'formattedValue': '$ 355.00', 'minQuantity': None, 'maxQuantity': None, 'membershipLevel': 'NORMAL'}]"

# %%
df.iloc[0].savedPrice
# Out:
# "[{'currencyIso': 'HKD', 'value': 195.00002499999994, 'priceType': 'DISCOUNT', 'formattedValue': '$ 195.00', 'minQuantity': None, 'maxQuantity': None, 'membershipLevel': 'NORMAL'}]"

# %%
df.iloc[3].perfectPartnerPromotion
# Out:
# "{'code': 'Redemption_H0888001_20200528_HHTissue_Combat', 'name': '威滅換購優惠', 'label': '換購優惠', 'description': '【換購優惠】凡購買精選家居清潔/紙品產品，即可以$29.9換購威滅速效曱甴藥餌典雅版/速效殺蟻藥餌<br />以$39.9換購威滅速效曱甴藥餌<br />換購貨品數量有限，換完即止。<br />優惠期至2020年6月11日。', 'colorCode': '#FF3333', 'discountType': 'QUANTITY'}"
